# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./store/covid-2-income.csv', index_col=0)

# %%
df.head()
# Out:
#         income
# 0     0.000000
# 1    30.000000
# 2   346.153846
# 3   414.615385
# 4  1150.000000

# %%
plt.plot(df.index, df.income)
